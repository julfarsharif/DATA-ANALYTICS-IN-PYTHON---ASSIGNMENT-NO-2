# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
import pandas as pd

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
population=pd.read_csv('C:\\Users\\aedpu\\Downloads\\india_population.csv')

# %%
population=population.head()

# %%
population
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020  1380004385             0.99       13586631         -532687
# 1  2019  1366417754             1.02       13775474         -532687
# 2  2018  1352642280             1.04       13965495         -532687
# 3  2017  1338676785             1.07       14159536         -532687
# 4  2016  1324517249             1.10       14364846         -532687
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        28.4            2.24              464         35.0         483098640
# 1        27.1            2.36              460         34.5         471828295
# 2        27.1            2.36              455         34.1         460779764
# 3        27.1            2.36              450         33.6         449963381
# 4        27.1            2.36              445         33.2         439391699
#
#    Country's Share of World Pop  World Population  India Global Rank
# ...

# %%
plt.bar(population['Year'], population['Population'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot(population['Year'],population['World Population'],linestyle='dashdot')

# %%
plt.pie(population ['Population'],labels= population['Year'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x191b26dabe0>,
# ...
#  [Text(0.8815697839497365, 0.6579017525640245, '2020'),
#   Text(-0.37330824555935777, 1.0347178136078428, '2019'),
#   Text(-1.0991778245967914, -0.042521875719042174, '2018'),
#   Text(-0.3058982242464952, -1.0566107497100534, '2017'),
#   Text(0.8982344227592355, -0.6349605670987634, '2016')],
#  [Text(0.4808562457907653, 0.3588555013985588, '20.4%'),
#   Text(-0.2036226793960133, 0.5643915346951869, '20.2%'),
#   Text(-0.5995515406891588, -0.02319375039220482, '20.0%'),
#   Text(-0.16685357686172464, -0.5763331362054837, '19.8%'),
#   Text(0.48994604877776476, -0.3463421275084163, '19.6%')])

# %%
sns.distplot(population['Urban Pop %'])
# Out:
# C:\Users\aedpu\AppData\Local\Temp\ipykernel_2056\606104736.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population['Urban Pop %'])
# <Axes: xlabel='Urban Pop %', ylabel='Density'>

# %%
sns.relplot(x='Fertility Rate',y="Urban Pop %",data=population,col="Year",hue='Year',style="Year",kind="scatter")

# %%
sns.catplot(x ="Fertility Rate",y ='Year',kind='box',data=population)

# %%
sns.regplot(x='Year',y='Urban Pop %',data=population)
# Out:
# <Axes: xlabel='Year', ylabel='Urban Pop %'>

# %%
sns.pairplot(population,hue='Year',palette='Set2')

# %%
time= np.arange(0,50,0.5)

# %%
time
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#         5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#        11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ,
#        16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. , 20.5, 21. , 21.5,
#        22. , 22.5, 23. , 23.5, 24. , 24.5, 25. , 25.5, 26. , 26.5, 27. ,
#        27.5, 28. , 28.5, 29. , 29.5, 30. , 30.5, 31. , 31.5, 32. , 32.5,
#        33. , 33.5, 34. , 34.5, 35. , 35.5, 36. , 36.5, 37. , 37.5, 38. ,
#        38.5, 39. , 39.5, 40. , 40.5, 41. , 41.5, 42. , 42.5, 43. , 43.5,
#        44. , 44.5, 45. , 45.5, 46. , 46.5, 47. , 47.5, 48. , 48.5, 49. ,
#        49.5])

# %%
amplitude = np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.47942554,  0.84147098,  0.99749499,  0.90929743,
#         0.59847214,  0.14112001, -0.35078323, -0.7568025 , -0.97753012,
#        -0.95892427, -0.70554033, -0.2794155 ,  0.21511999,  0.6569866 ,
#         0.93799998,  0.98935825,  0.79848711,  0.41211849, -0.07515112,
#        -0.54402111, -0.87969576, -0.99999021, -0.87545217, -0.53657292,
#        -0.0663219 ,  0.42016704,  0.80378443,  0.99060736,  0.93489506,
#         0.65028784,  0.20646748, -0.28790332, -0.71178534, -0.96139749,
#        -0.97562601, -0.75098725, -0.34248062,  0.14987721,  0.60553987,
#         0.91294525,  0.99682979,  0.83665564,  0.471639  , -0.00885131,
#        -0.48717451, -0.8462204 , -0.99808203, -0.90557836, -0.59135753,
#        -0.13235175,  0.35905835,  0.76255845,  0.97935764,  0.95637593,
#         0.69924003,  0.27090579, -0.22375564, -0.66363388, -0.94103141,
#        -0.98803162, -0.79312724, -0.40403765,  0.08397446,  0.55142668,
# ...

# %%
plt.plot(time,amplitude)

# %%
sns.set(style ='white')

# %%
random = np.random.randn(100)

# %%
random
# Out:
# array([ 1.27405369,  2.20930779,  1.30019973, -1.03348379,  1.27793961,
#         0.5319052 ,  0.65787173,  0.28291783,  0.5646941 , -1.06501016,
#        -1.18410481,  0.54592498,  1.00379054, -0.40709191, -0.52966619,
#        -0.82518259, -2.76512443,  1.09044077,  0.35528433, -0.77398292,
#         1.40850704,  0.66612685,  0.62315344, -0.74682312,  0.18024087,
#         1.57138502,  1.20220625, -1.03325927, -0.50214707, -0.34426956,
#         0.510626  , -0.86393033,  0.1521769 ,  1.55363471, -1.92417881,
#        -1.7379657 , -2.1559332 ,  0.02324852, -1.62071036,  1.06938596,
#         0.01876358,  1.53937016,  1.08403433,  0.04820541,  1.05633686,
#         0.63477385,  0.84565069,  0.57967482, -0.52066419, -0.15240684,
#        -0.85633201,  0.21923054, -0.08066835, -1.48264036,  0.29361245,
#        -2.16010302,  0.69207483,  1.0077518 , -1.74158039, -1.07790178,
#        -0.74534199, -0.72589696,  0.17332057, -0.09398588, -1.04095849,
# ...

# %%
sns.distplot(random)
# Out:
# C:\Users\aedpu\AppData\Local\Temp\ipykernel_2056\1899859526.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random)
# <Axes: ylabel='Density'>
